# %%
import pandas as pd

# %%
df_stc = pd.read_csv("./data/2015_Street_Tree_Census_-_Tree_Data.csv")
df_ftp = pd.read_csv("./data/Forestry_Tree_Points.csv")

# %%
df_stc.columns
# Out:
# Index(['tree_id', 'block_id', 'created_at', 'tree_dbh', 'stump_diam',
#        'curb_loc', 'status', 'health', 'spc_latin', 'spc_common', 'steward',
#        'guards', 'sidewalk', 'user_type', 'problems', 'root_stone',
#        'root_grate', 'root_other', 'trunk_wire', 'trnk_light', 'trnk_other',
#        'brch_light', 'brch_shoe', 'brch_other', 'address', 'postcode',
#        'zip_city', 'community board', 'borocode', 'borough', 'cncldist',
#        'st_assem', 'st_senate', 'nta', 'nta_name', 'boro_ct', 'state',
#        'latitude', 'longitude', 'x_sp', 'y_sp', 'council district',
#        'census tract', 'bin', 'bbl'],
#       dtype='object')

# %%
df_ftp.columns
# Out:
# Index(['OBJECTID', 'DBH', 'TPStructure', 'TPCondition', 'StumpDiameter',
#        'PlantingSpaceGlobalID', 'Geometry', 'GlobalID', 'GenusSpecies',
#        'CreatedDate', 'UpdatedDate', 'PlantedDate', 'RiskRating',
#        'RiskRatingDate', 'Location'],
#       dtype='object')

# %%
ftp_species = []
for spec in df_ftp.GenusSpecies.unique().tolist():
    parts = str(spec).split(' - ')
    if len(parts) > 1:
        standard = parts[1].lower()
        ftp_species.append(standard)
        
stc_species = [str(x).lower() for x in df_stc.spc_common.unique().tolist()]

matches = 0
unmatched = []
for spec in ftp_species:
    if spec not in stc_species:
        unmatched.append(spec)
    else:
        matches += 1

print("%d without match, %d matches" % (len(unmatched), matches))
print(unmatched)
# Out:
# 455 without match, 107 matches
# ['apple', 'oak', 'unknown', 'northern catalpa', 'common linden', 'thornless honeylocust', 'maidenhair tree', 'japanese pagoda tree', 'cherry plum', "'redstone' cornelian cherry", "'green leaf' japanese flowering cherry", 'american sycamore', 'chokecherry', "'not green leaf' japanese flowering cherry", 'goldenrain tree', "'crimson king' norway maple", "'not green leaf' norway maple", 'japanese flowering crabapple', 'northern pin oak', 'american basswood', "'szeleste' silver linden", 'white willow', 'eastern white pine', 'largeleaf linden', 'sargent oak', "'fastigiata' european hornbeam", "'regent' japanese pagodatree", 'european larch', 'overcup oak', 'sawara-cypress', 'live oak', 'bitternut hickory', 'hophornbeam', 'european turkey oak', "devil's walkingstick", 'caucasian linden', "'green vase' zelkova", 'american witchhazel', 'red horse-chestnut', 'prairie crabapple', 'alternateleaf dogwood', 'amur corktree', "'redmond' american linden", 'balsam fir', "'moraine' sweetgum", 'tuliptree', 'chinese crabapple', "'bloodgood' london planetree", 'southern catalpa', 'silver fir', "'city sprite' zelkova", "'fort mcnair' ruby red horsechestnut", 'bristly locust', "'skyline' thornless honeylocust", 'austrian pine', 'shagbark hickory', 'tatarian maple', 'yellow birch', 'post oak', 'european white birch', 'japanese flowering cherry', "'sterling' silver linden", 'american chestnut', "'patriot' elm", 'gray birch', 'fraser fir', 'japanese cedar', "sargent's apple", 'lagerstroemia', 'red buckeye', 'princesstree', "'fastigiate' ginkgo", 'common serviceberry', 'pacific dogwood', 'striped maple', 'american mountain ash', 'peking tree lilac', 'turkey oak', 'sweetbay', 'chinese juniper', 'holly oak', 'white fir', "'harvest gold' crabapple", 'western redcedar', "'frisia' black locust", "'greenspire' littleleaf linden", 'allegheny serviceberry', "'glauca' blue spruce", 'lilac chastetree', 'chinkapin oak', 'japanese walnut', 'freeman maple', 'silktree', "'magnifica' hackberry", 'carolina silverbell', "'streetkeeper' thornless honeylocust", "'espresso' kentucky coffee tree", 'fringetree', 'sweet birch', "shumard's oak", "'kwanzan' flowering cherry", "'athena' elm", 'port orford cedar', 'osage orange', "'gold rush' dawn redwood", 'asian white birch', "'allee' chinese elm", 'american snowbell', "'green pillar' pin oak", 'cucumber tree', 'european smoketree', "'crimson point' cherry plum", "'millstone' japanese pagodatree", "'harvest gold' mongolian linden", 'swiss stone pine', 'golden chain tree', "'imperial' thornless honeylocust", "'appalachian red' eastern redbud", "'merlot' european bird cherry", "'halka' thornless honeylocust", 'tamarack', 'european hackberry', "'green mountain' silver linden", "'thundercloud' cherry plum", "'ivory silk' japanese tree lilac", 'russian olive', "'valley forge' american elm", "'natchez' crapemyrtle", 'two-wing silverbell', 'english yew', 'bunchberry dogwood', "'autumn brilliance' serviceberry", 'blue ash', 'southwestern white pine', "'adams' crabapple", "'mcsentry' american linden", "'pioneer' elm", "'shawnee brave' bald cypress", "'newport' cherry plum", 'sourwood', 'american holly', "'princeton' american elm", 'horsechestnut', 'compton oak', 'pecan', "'lavellus' hawthorn", "'fastigiata' goldenraintree", 'american hazelnut', "'gold candle' goldenraintree", "'jack pear' callery pear", "'flame' amur maple", 'canadian serviceberry', 'shellbark hickory', 'upright english oak', 'chestnut oak', "'columnar' ginkgo", "'redpointe' red maple", 'blackjack oak', "'tuskogee' crapemyrtle", "'cherokee' sweetgum", "'corinthian' littleleaf linden", "'silver ball' callery pear", 'willow', 'serbian spruce', 'deodar cedar', 'chinese magnolia', "'pendula' higan cherry", "'autumnalis' higan cherry", "'october glory' red maple", 'oakleaf mountain ash', "'rose lanterns' goldenraintree", "'american dream' swamp white oak", "'golden glory' cornelian cherry dogwood", 'laurel oak', "'exclamation' london planetree", "'spires' flowering cherry", " ...

# %%
import re

def remove_symbols(s):
    return re.sub(r'[^a-zA-Z0-9 ]', '', s)

def to_camel_case(s):
    parts = s.split(' ')
    return parts[0].lower() + ''.join(word.title() for word in parts[1:])

def remove_symbols_and_camel_case(strings):
    return [to_camel_case(remove_symbols(s)) for s in strings]

# %%
cc = remove_symbols_and_camel_case(ftp_species)
for value in ftp_species:
    print("case %s = \"%s\"" % (to_camel_case(remove_symbols(value)), value))
# Out:
# ['maple',
#  'mulberry',
#  'spruce',
#  'apple',
#  'pine',
#  'cherry',
#  'oak',
#  'unknown',
#  'holly',
#  'redMaple',
#  'easternRedbud',
#  'blackCherry',
#  'norwayMaple',
#  'northernCatalpa',
#  'commonLinden',
#  'londonPlanetree',
#  'japaneseZelkova',
#  'sweetgum',
#  'thornlessHoneylocust',
#  'maidenhairTree',
#  'silverMaple',
#  'pinOak',
#  'calleryPear',
#  'littleleafLinden',
#  'japanesePagodaTree',
#  'greenAsh',
#  'cherryPlum',
#  'silverLinden',
#  'katsuraTree',
#  'europeanHornbeam',
#  'redstoneCornelianCherry',
#  'ash',
#  'greenLeafJapaneseFloweringCherry',
#  'americanSycamore',
#  'americanHornbeam',
#  'chokecherry',
#  'notGreenLeafJapaneseFloweringCherry',
#  'dawnRedwood',
#  'sugarMaple',
#  'sawtoothOak',
#  'siberianElm',
#  'northernRedOak',
#  'whiteOak',
#  'hawthorn',
#  'whiteAsh',
#  'treeOfHeaven',
#  'commonHackberry',
#  'goldenrainTree',
#  'swampWhiteOak',
#  'crimsonKingNorwayMaple',
#  'notGreenLeafNorwayMaple',
#  'tridentMaple',
#  'blackLocust',
#  'weepingWillow',
#  'americanElm',
#  'cornelianCherry',
#  'japaneseFloweringCrabapple',
#  'northernPinOak',
#  'blackOak',
#  'amurMaackia',
#  'americanBasswood',
#  'sycamoreMaple',
#  'americanBeech',
#  'horseChestnut',
#  'szelesteSilverLinden',
#  'japaneseMaple',
#  'scarletOak',
#  'persianIronwood',
#  'chineseElm',
#  'whiteWillow',
#  'willowOak',
#  'pondCypress',
#  'cockspurHawthorn',
#  'paperbarkMaple',
#  'baldCypress',
#  'hedgeMaple',
#  'easternWhitePine',
#  'largeleafLinden',
#  'amurMaple',
#  'sargentOak',
#  'shingleOak',
#  'fastigiataEuropeanHornbeam',
#  'regentJapanesePagodatree',
#  'japaneseTreeLilac',
#  'europeanLarch',
#  'hardyRubberTree',
#  'overcupOak',
#  'easternCottonwood',
#  'sawaracypress',
#  'norwaySpruce',
#  'liveOak',
#  'bitternutHickory',
#  'catalpa',
#  'hophornbeam',
#  'europeanTurkeyOak',
#  'englishOak',
#  'devilsWalkingstick',
#  'caucasianLinden',
#  'greenVaseZelkova',
#  'boxelder',
#  'americanWitchhazel',
#  'redHorsechestnut',
#  'floweringDogwood',
#  'blackgum',
#  'prairieCrabapple',
#  'alternateleafDogwood',
#  'amurCorktree',
#  'sassafras',
#  'redmondAmericanLinden',
#  'pignutHickory',
#  'kentuckyCoffeetree',
#  'balsamFir',
#  'moraineSweetgum',
#  'tuliptree',
#  'chineseCrabapple',
#  'bloodgoodLondonPlanetree',
#  'southernCatalpa',
#  'silverFir',
#  'citySpriteZelkova',
#  'fortMcnairRubyRedHorsechestnut',
#  'bristlyLocust',
#  'skylineThornlessHoneylocust',
#  'austrianPine',
#  'shagbarkHickory',
#  'bigtoothAspen',
#  'europeanBeech',
#  'tatarianMaple',
#  'easternHemlock',
#  'yellowBirch',
#  'postOak',
#  'europeanWhiteBirch',
#  'japaneseFloweringCherry',
#  'paperBirch',
#  'southernRedOak',
#  'amurMaple',
#  'sterlingSilverLinden',
#  'serviceberry',
#  'blueSpruce',
#  'americanChestnut',
#  'patriotElm',
#  'blackMaple',
#  'grayBirch',
#  'fraserFir',
#  'chineseFringetree',
#  'japaneseCedar',
#  'redPine',
#  'sargentsApple',
#  'lagerstroemia',
#  'arborvitae',
#  'serviceberry',
#  'blackWalnut',
#  'kentuckyYellowwood',
#  'magnolia',
#  'redBuckeye',
#  'burOak',
#  'princesstree',
#  'fastigiateGinkgo',
#  'japaneseSnowbell',
#  'commonServiceberry',
#  'pacificDogwood',
#  'stripedMaple',
#  'americanMountainAsh',
#  'riverBirch',
#  'pekingTreeLilac',
#  'southernMagnolia',
#  'turkeyOak',
#  'sweetbay',
#  'chineseJuniper',
#  'atlanticWhiteCedar',
#  'hollyOak',
#  'whiteFir',
#  'oklahomaRedbud',
#  'harvestGoldCrabapple',
#  'westernRedcedar',
#  'frisiaBlackLocust',
#  'greenspireLittleleafLinden',
#  'alleghenyServiceberry',
#  'glaucaBlueSpruce',
#  'lilacChastetree',
#  'chinkapinOak',
#  'japaneseWalnut',
#  'freemanMaple',
#  'atlasCedar',
#  'silktree',
#  'magnificaHackberry',
#  'carolinaSilverbell',
#  'streetkeeperThornlessHoneylocust',
#  'japaneseHornbeam',
#  'espressoKentuckyCoffeeTree',
#  'europeanAlder',
#  'fringetree',
#  'sweetBirch',
#  'shumardsOak',
#  'kwanzanFloweringCherry',
#  'easternRedcedar',
#  'athenaElm',
#  'portOrfordCedar',
#  'kousaDogwood',
#  'turkishHazelnut',
#  'pitchPine',
#  'chineseChestnut',
#  'osageOrange',
#  'goldRushDawnRedwood',
#  'asianWhiteBirch',
#  'alleeChineseElm',
#  'americanSnowbell',
#  'greenPillarPinOak',
#  'cucumberTree',
#  'europeanSmoketree',
#  'crimsonPointCherryPlum',
#  'millstoneJapanesePagodatree',
#  'harvestGoldMongolianLinden',
#  'swissStonePine',
#  'goldenChainTree',
#  'imperialThornlessHoneylocust',
#  'appalachianRedEasternRedbud',
#  'quakingAspen',
#  'merlotEuropeanBirdCherry',
#  'halkaThornlessHoneylocust',
#  'tamarack',
#  'europeanHackberry',
#  'greenMountainSilverLinden',
#  'thundercloudCherryPlum',
#  'ivorySilkJapaneseTreeLilac',
#  'russianOlive',
#  'valleyForgeAmericanElm',
#  'natchezCrapemyrtle',
#  'twowingSilverbell',
#  'englishYew',
#  'bunchberryDogwood',
#  'autumnBrillianceServiceberry',
#  'blueAsh',
#  'southwesternWhitePine',
#  'adamsCrabapple',
#  'mcsentryAmericanLinden',
#  'pioneerElm',
#  'shawneeBraveBaldCypress',
#  'newportCherryPlum',
#  'sourwood',
#  'americanHolly',
#  'douglasfir',
#  'princetonAmericanElm',
#  'horsechestnut',
#  'comptonOak',
#  'pecan',
#  'lavellusHawthorn',
#  'fastigiataGoldenraintree',
#  'americanHazelnut',
#  'goldCandleGoldenraintree',
#  'jackPearCalleryPear',
#  'flameAmurMaple',
#  'canadianServiceberry',
#  'shellbarkHickory',
#  'uprightEnglishOak',
#  'chestnutOak',
#  'columnarGinkgo',
#  'redpointeRedMaple',
#  'blackjackOak',
#  'tuskogeeCrapemyrtle',
#  'cherokeeSweetgum',
#  'corinthianLittleleafLinden',
#  'silverBallCalleryPear',
#  'willow',
#  'serbianSpruce',
#  'deodarCedar',
#  'scotsPine',
#  'chineseMagnolia',
#  'pendulaHiganCherry',
#  'autumnalisHiganCherry',
#  'octoberGloryRedMaple',
#  'oakleafMountainAsh',
#  'roseLanternsGoldenraintree',
#  'americanDreamSwampWhiteOak',
#  'goldenGloryCornelianCherryDogwood',
#  'laurelOak',
#  'ohioBuckeye',
#  'exclamationLondonPlanetree',
#  'spiresFloweringCherry',
#  'aristocratCalleryPear',
#  'europeanBirdcherry',
#  'regalPrinceOak',
#  'glaucaEasternRedCedar',
#  'tupeloTowerBlackGum',
#  'beaconSwampWhiteOak',
#  'virginiaPine',
#  'forestPansyEasternRedbud',
#  'unizamLittleleafLinden',
#  'clevelandSelectCalleryPear',
#  'autumnGoldGinkgo',
#  'yoshinoJapaneseCedar',
#  'starburstAmurMaackia',
#  'shantungMaple',
#  'ruggedRidgeMiyabeMaple',
#  'armstrongRedMaple',
#  'okameCherry',
#  'briotiiRubyRedHorsechestnut',
#  'leprechaunGreenAsh',
#  'duraheatRiverBirch',
#  'snowcapJapaneseTreeLilac',
#  'greenGiantArborvitae',
#  'variegataZelkova',
#  'redSunsetRedMaple',
#  'pallidaCommonLinden',
#  'shirofugenJapaneseFloweringCherry',
#  'evelynHedgeMaple',
#  'heritageRiverBirch',
#  'continentalAppealAmericanLinden',
#  'saskatoonServiceberry',
#  'commonSilverbell',
#  'worplesdonSweetgum',
#  'whiteSpruce',
#  'villageGreenZelkova',
#  'columbiaLondonPlanetree',
#  'norwegianSunsetShangtungMaple',
#  'wirelessZelkova',
#  'sugarberry',
#  'accoladeElm',
#  'holmfordCalleryPear',
#  'commemorationSugarMaple',
#  'prairieTitanKentuckyCoffeeTree',
#  'windoverGoldGinkgo',
#  'mountainSilverbell',
#  'autumnBlazeRedMaple',
#  'orientalPaperbush',
#  'newWorldRedMaple',
#  'chicagolandHackberry',
#  'emeraldAvenueEuropeanHornbeam',
#  'arnoldPinkCarolinaSilverbellTree',
#  'halkaZelkova',
#  'winterKingGreenHawthorn',
#  'emeraldPointeHardyRubberTree',
#  'limberPine',
#  'snowGooseCherry',
#  'karpickRedMaple',
#  'prestigeLittleleafLinden',
#  'homesteadElm',
#  'fivestamenTamarisk',
#  'satinShadowSilverLinden',
#  'bejingGoldPekingLilac',
#  'amanowagawaCherry',
#  'shamrockLittleleafLinden',
#  'magyarGinkgo',
#  'sweetshadeAmericanYellowwood',
#  'ponderosaPine',
#  'jeffersonElm',
#  'mountStHelensCherryPlum',
#  'mtFujiCherry',
#  'legendAmericanLinden',
#  'commonFilbert',
#  'summerGlowEuropeanBirdCherry',
#  'muskogeeCrapemyrtle',
#  'sarahsFavoriteCrapemyrtle',
#  'washingtonHawthorn',
#  'pumpkinAsh',
#  'skywardBaldCypress',
#  'columbusEasternRedbud',
#  'patmoreGreenAsh',
#  'starMagnolia',
#  'canadaRedChokecherry',
#  'eyeStopperAmurCorkTree',
#  'triumphElm',
#  'blackAsh',
#  'mushashinoZelkova',
#  'summerCharmPekingLilac',
#  'yoshinoCherry',
#  'flameTatarianMaple',
#  'yellowBuckeye',
#  'japaneseStewartia',
#  'shirotaeFloweringCherry',
#  'venusDogwood',
#  'snowconeJapaneseSnowbell',
#  'buckeye',
#  'cherokeeBraveFloweringDogwood',
#  'fragrantSnowbell',
#  'dianeWitchHazel',
#  'asplenifoliaEuropeanBeech',
#  'waterOak',
#  'springSunCornelianCherryDogwood',
#  'krauterVesuviusCherryPlum',
#  'columnarisSargentCherry',
#  'rusticaRubraSaucerMagnolia',
#  'fairmontGinkgo',
#  'emeraldSunshineElm',
#  'atropurpureumSycamoreMaple',
#  'akebonoYoshinoCherry',
#  'emeraldCityTulipPoplar',
#  'kindredSpiritOak',
#  'sargentCherry',
#  'redRageBlackGum',
#  'laurelhurstCrimeanLinden',
#  'hetziiChineseJuniper',
#  'crippsiiGoldenHinokiCypress',
#  'pinkSpireCrabapple',
#  'chinaSnowPekingLilac',
#  'bottlebrushBuckeye',
#  'ozarkWitchhazel',
#  'yellowBuckeye',
#  'rubyVasePersianIronwood',
#  'hightowerWillowOak',
#  'dynastyChineseElm',
#  'kobusMagnolia',
#  'orientalSpruce',
#  'prospectorElm',
#  'uppertonWillowOak',
#  'donaldWymanCrabapple',
#  'arnoldTulipPoplar',
#  'bigleafMagnolia',
#  'centurionCrabapple',
#  'fallFiestaSugarMaple',
#  'bosqueChineseElm',
#  'nuttallOak',
#  'hollyJolivetteCherry',
#  'chinesePistache',
#  'panicleHydrangea',
#  'oregonWhiteOak',
#  'redJewelCrabapple',
#  'robinHillCanadianServiceberry',
#  'europeanMountainAsh',
#  'nativeFlameAmericanHornbeam',
#  'japaneseBlackPine',
#  'prariefireCrabapple',
#  'forumBalckGum',
#  'slenderSilhouetteSweetgum',
#  'shademasterThornlessHoneylocust',
#  'princetonSentryGinkgo',
#  'glenlevynLittleleafLinden',
#  'emeraldPagodaJapaneseSnowbell',
#  'purpleFountainEuropeanBeech',
#  'heleneWitchHazel',
#  'koreanSunPear',
#  'crosswicksRedEasternRedbud',
#  'umbrellatree',
#  'schmidtsPurpleleafSandCherry',
#  'cupressifoliaEasternRedCedar',
#  'tableMountainPine',
#  'pacificBrilliancePinOak',
#  'rockyMountainMaple',
#  'cardinalCrabapple',
#  'vanderwolfLimberPine',
#  'englishHolly',
#  'blueHavenJuniper',
#  'camellia',
#  'bhutanPine',
#  'championsGoldDogwood',
#  'tea',
#  'yellowhorn',
#  'autumnBlazeFreemanMaple',
#  'nellieRStevensHolly',
#  'cedarOfLebanon',
#  'japaneseLarch',
#  'zumiCrabapple',
#  'nootkaFalsecypress',
#  'serviceberry',
#  'dreamcatcherCherry',
#  'whiteShieldOsageOrange',
#  'redBuckeye',
#  'constellationDogwood',
#  'happidazeSweetgum',
#  'fastigiataEasternWhitePine',
#  'appalachianSpringFloweringDogwood',
#  'royalBurgundyFloweringCherry',
#  'lancelotCrabapple',
#  'sugartymeCrabapple',
#  'perkinsPinkAmericanYellowwood',
#  'bowhallRedMaple',
#  'keteleeriChineseJuniper',
#  'stoneHillCalleryPear',
#  'koreanOak',
#  'crimsonCloudHawthorn',
#  'chanticleerCalleryPear',
#  'baumanniHorsechestnut',
#  'frontierElm',
#  'rubySlippersAmurMaple',
#  'kousaDogwood',
#  'purpleRobeBlackLocust',
#  'angelicaJapaneseCedar',
#  'purpureaCatalpa',
#  'cherokeePrincessFloweringDogwood',
#  'chineseCatalpa',
#  'skyrocketEnglishOak',
#  'niobeWhiteWillow',
#  'robinsonCrabapple',
#  'oklahomaOklahomaRedbud',
#  'fatAlbertColoradoBlueSpruce',
#  'cascadeSnowYoshinoCherry',
#  'globosaEuropeanDwarfCherry',
#  'praireSentinalHackberry',
#  'cardinalRoyalMountainAsh',
#  'heartsOfGoldEasternRedbud',
#  'pinkFlairSargentCherry',
#  'ultrazamHackberry',
#  'royalRaindropsCrabapple',
#  'galaxyMagnolia',
#  'nutansBaldCypress',
#  'avondaleChineseRedbud',
#  'StateStreetMiyabeMaple',
#  'wildfireBlackGum',
#  'dawyckiiPurpleEuropeanBeech',
#  'tricolorEuropeanBeech',
#  'riversiiEuropeanBeech',
#  'graceSmoketree',
#  'mortonGlossyElm',
#  'loblollyPine',
#  'snowCharmJapaneseSnowbell',
#  'pacificSunsetShangtungMaple',
#  'hotWingsTatarianMaple',
#  'whiteRedbud',
#  'scarsenFreemanMaple',
#  'nuttallOak',
#  'nikkoMaple',
#  'crimsonSunsetShangtungMaple',
#  'koreanStewartia',
#  'patternPerfectTatarianMaple',
#  'shangriLaGinkgo',
#  'newHarmonyElm',
#  'columnarisRanchoSargentCherry',
#  'metroGoldHedgeMaple',
#  'summerburstgoldenraintree',
#  'butterfliesMagnolia',
#  'cherokeeSunsetFloweringDogwood',
#  'summerStarsDogwood',
#  'everclearChineseElm',
#  'springSnowCrabapple',
#  'palibinKoreanLilac',
#  'drMerrilLoebnerMagnolia',
#  'northernBayberry',
#  'royalPurpleSmoketree',
#  'beakedHazelnut',
#  'redbudCrabapple',
#  'koreanMountainAsh',
#  'elizabethMagnolia',
#  'giantSequoia',
#  'morrisDebonairBaldCypress',
#  'auroraDogwood',
#  'himalayanCedar',
#  'newHorizonElm',
#  'vanessaPersianIronwood',
#  'dolgoCrabapple',
#  'grandmasterSweetgum',
#  'princetonSnowcloudSargentCherry',
#  'springFlurryAlleghenyServiceberry',
#  'juneSnowDogwood',
#  'tinaSargentsCrabapple',
#  'maacnificentAmurMaackia',
#  'sunValleyRedMaple',
#  'ruggedCharmTatarianMaple',
#  'janeMagnolia',
#  'royalWhiteEasternRedbud',
#  'greenMountainSugarMaple',
#  'silverLiningSilverLinden',
#  'dawyckEuropeanBeech',
#  'goldenCollonadeGinkgo',
#  'urbanPinnacleBurOak',
#  'accoladeFloweringCherry',
#  'gumDropBlackGum',
#  'radiantRoseDogwood',
#  'sevensonFlower',
#  'greatWallPekingLilac',
#  'commonPersimmon',
#  'kiwiSunsetZelkova',
#  'profusionCrabapple',
#  'kashmirDeodarCedar']
